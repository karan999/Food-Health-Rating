# %%
from pyspark.sql import SparkSession 
from pyspark.sql.types import * 
from pyspark.sql.functions import *
from pyspark.sql.window import Window
from pyspark.sql import functions as f
import pandas as pd 
import numpy as np
import os 
import xmltodict
import json 
import pandas as pd

# %%
spark = SparkSession.builder.appName( 'Ealing' ).getOrCreate()

# %% [markdown]
# # Coverting XML to Dict

# %%
with open('D:/Side Project/Datasets/Food Health Rating/Data/Ealing.xml') as fd:
    doc = xmltodict.parse(fd.read())

# %%
with open('D:/Side Project/Datasets/Food Health Rating/Data/Ealing_Json.txt', 'w') as outfile:
    json.dump(doc, outfile)

# %%
{"FHRSID": "610257",
 "LocalAuthorityBusinessID": "PI/000173335",
 "BusinessName": "97p Stores",
 "BusinessType": "Retailers - other", 
 "BusinessTypeID": "4613",
 "AddressLine1": "66 Broadway", 
 "AddressLine2": "West Ealing",
 "PostCode": "W13 0SY", 
 "RatingValue": "1", 
 "RatingKey": "fhrs_1_en-GB", 
 "RatingDate": "2016-01-30",
 "LocalAuthorityCode": "509",
 "LocalAuthorityName": "Ealing",
 "LocalAuthorityWebSite": "https://www.ealing.gov.uk/info/201150/food_hygiene_and_safety",
 "LocalAuthorityEmailAddress": "foodsafety@ealing.gov.uk",
 "Scores": {"Hygiene": "10", "Structural": "5", "ConfidenceInManagement": "20"},
 "SchemeType": "FHRS", 
 "NewRatingPending": "False", 
 "Geocode": {"Longitude": "-0.32524100000000", "Latitude": "51.51054700000000"}},

# %%
ealing_df = pd.DataFrame.from_dict(doc['FHRSEstablishment']['EstablishmentCollection']['EstablishmentDetail'])

# %%
def convert_dict_scores( df, scores ):
    
    if scores == 'Y':  #extracting values for Scores 
    
        #create a temporary dataframe to store the dictionary values 

        temp_df = pd.DataFrame( columns = ['Hygiene','Structural','ConfidenceInManagement'] )

        # Populate temp_df dataframe

        for (i,r) in df.iterrows():

            e = r['Scores']

            try:

                temp_df.loc[i] = [e['Hygiene'], e['Structural'], e['ConfidenceInManagement']]

            except TypeError:

                temp_df.loc[i] = 'None'

        df_1 = pd.concat([df, temp_df] , axis = 1)

        del df_1['Scores']
        
    else: #extracting values for geocode
        
        temp_df = pd.DataFrame( columns = ['Longitude','Latitude'] )
    
    # Populate temp_df dataframe
    
        for (i,r) in df.iterrows():

            e = r['Geocode']

            try:

                temp_df.loc[i] = [e['Longitude'], e['Latitude']]

            except TypeError:

                temp_df.loc[i] = 'None'

        df_1 = pd.concat([df, temp_df] , axis = 1)

        del df_1['Geocode']
        
    
    return df_1

# %%
ealing_df = convert_dict_scores( ealing_df , 'Y')

# %%
ealing_df = convert_dict_scores( ealing_df , 'N')

# %%
ealing_df.columns
# Out:
# Index(['FHRSID', 'LocalAuthorityBusinessID', 'BusinessName', 'BusinessType',
#        'BusinessTypeID', 'RatingValue', 'RatingKey', 'RatingDate',
#        'LocalAuthorityCode', 'LocalAuthorityName', 'LocalAuthorityWebSite',
#        'LocalAuthorityEmailAddress', 'SchemeType', 'NewRatingPending',
#        'AddressLine1', 'AddressLine2', 'AddressLine3', 'AddressLine4',
#        'PostCode', 'RightToReply', 'Hygiene', 'Structural',
#        'ConfidenceInManagement', 'Longitude', 'Latitude'],
#       dtype='object')

# %%
ealing_df = ealing_df.replace(to_replace = 'None' , value = np.nan)

# %%
ealing_df
# Out:
#        FHRSID LocalAuthorityBusinessID  \
# 0     1017491                  CH00130
# 1      962896                  CP00454
# 2      840152             PI/000182063
# 3      590655             PI/000173183
# 4      610257             PI/000173335
# 5      391740             PI/000054112
# 6      833588             PI/000061231
# 7      393584             PI/000168095
# 8     1005361                  CP00781
# 9      610244             PI/000055476
# 10     851196             PI/000182230
# 11     559838             PI/000172994
# 12     391521             PI/000026454
# 13     907986                  CP00102
# 14     927628                  CP00211
# 15     907983                  CP00099
# 16     985122                  CH00071
# 17     941786                  CP00267
# 18     997839                  CP00731
# 19     393577             PI/000168078
# 20     941821              PI000182462
# 21     840161             PI/000182088
# 22    1005362                  CP00782
# 23     393336             PI/000162645
# 24     701486             PI/000175824
# 25     927629                  CP00212
# 26     941792                  CP00274
# 27     782500             PI/000177933
# 28     962904                  CP00462
# 29     985146                  CP00622
# ...       ...                      ...
# 2789   828744             PI/000179312
# 2790   639959             PI/000175551
# 2791  1002922                  CP00768
# 2792   853680             PI/000182256
# 2793   849057             PI/000182179
# 2794   985132                  CP00567
# 2795  1002925                  CP00771
# 2796  1002926                  CP00772
# 2797   391330             PI/000005209
# 2798   840182             PI/000182123
# 2799   639941             PI/000175502
# 2800   974706                  CP00555
# 2801   393323             PI/000162594
# 2802   816050             PI/000179569
# 2803   591743             PI/000173314
# 2804   972977                  CP00524
# 2805   977723                  CP00549
# 2806   897264             PI/000182475
# 2807   745886             PI/000178980
# 2808   812626             PI/000179526
# 2809   782507             PI/000179361
# 2810   639918             PI/000175473
# 2811   430767             PI/000171475
# 2812  1011784                  CP00855
# 2813   972982                  CP00531
# 2814   930546                  CP00232
# 2815   449682             PI/000172055
# 2816   393417             PI/000162926
# 2817   957266                  CP00405
# 2818   954698                  CP00350
#
#                                 BusinessName  \
# 0                                 106 Coffee
# 1                               1070 Kitchen
# 2                             11 Coffee & Co
# 3                          5 Star Superstore
# 4                                 97p Stores
# 5                A - Z Premier Food And Wine
# 6                         A & C Roll Factory
# 7                             A 2 Zee's Cafe
# 8                                   A Demain
# 9                                  A G Wines
# 10                               A Night Inn
# 11                     A Piece of Cake Acton
# 12                         A Star Liquormart
# 13                              A To B Hotel
# 14                         A To Z Newsagents
# 15                         Abbey Lodge Hotel
# 16                           Abby's Workshop
# 17                                  ABC Cafe
# 18          ABCD Little Learners Day Nursery
# 19                             Abi Fast Food
# 20                             Abijos Snacks
# 21                                ABS Events
# 22            Abshar Restaurant & Banqueting
# 23                           Abu Afif Sweets
# 24                                  Abu Zaad
# 25    Abu Zaad at King Fahad Academy Canteen
# 26                                 Ace Diner
# 27                       Achinka Food & Wine
# 28                                Acorn Cafe
# 29                                 Acquolina
# ...                                      ...
# 2789                                Y Lounge
# 2790             Ya Sham Lebanese Restaurant
# 2791                              Yahya Cafe
# 2792                       Yaseen Restaurant
# 2793               Yasmin Al Sham/The Palace
# 2794                      Yasmina Restaurant
# 2795                  Yasser Charcoal Grills
# 2796                               Yat Sheng
# 2797                                   Yeraz
# 2798                             Yes 99 Plus
# 2799                           Yo Yo Noodles
# 2800                                 Yorica!
# 2801                            Yoyo Kitchen
# 2802                              Yumberries
# 2803                                   Yummy
# 2804                                Yummy Go
# 2805                         Yums And Crumbs
# 2806                                 Yum-Yum
# 2807                          Yvonne & Guite
# 2808                Yvon's Artisan Patissier
# 2809                                   Zabka
# 2810                                Zabka UK
# 2811                          Zahra Pharmacy
# 2812                         Zap Food Centre
# 2813                         Zara Halal Meat
# 2814                                   Zayka
# 2815                        Zeera Restaurant
# 2816                             Zeytoon Bar
# 2817                                    Zizi
# 2818                              Zyona Cafe
#
#                              BusinessType BusinessTypeID         RatingValue  \
# 0                   Manufacturers/packers           7839  AwaitingInspection
# 1                   Manufacturers/packers           7839                   5
# 2                 Restaurant/Cafe/Canteen              1                   5
# 3                       Retailers - other           4613                   4
# 4                       Retailers - other           4613                   1
# 5                       Retailers - other           4613                   5
# 6                   Manufacturers/packers           7839                   5
# 7                 Restaurant/Cafe/Canteen              1                   2
# 8                   Manufacturers/packers           7839  AwaitingInspection
# 9                       Retailers - other           4613              Exempt
# 10      Hotel/bed & breakfast/guest house           7842              Exempt
# 11                Other catering premises           7841                   5
# 12                      Retailers - other           4613              Exempt
# 13      Hotel/bed & breakfast/guest house           7842                   3
# 14                      Retailers - other           4613                   4
# 15      Hotel/bed & breakfast/guest house           7842                   2
# 16                  Manufacturers/packers           7839  AwaitingInspection
# 17                Restaurant/Cafe/Canteen              1                   5
# 18    Hospitals/Childcare/Caring Premises              5                   5
# 19                 Takeaway/sandwich shop           7844                   2
# 20                  Manufacturers/packers           7839  AwaitingInspection
# 21                Other catering premises           7841                   4
# 22                Restaurant/Cafe/Canteen              1  AwaitingInspection
# 23                  Manufacturers/packers           7839                   0
# 24                Restaurant/Cafe/Canteen              1                   4
# 25              School/college/university           7845                   1
# 26                Restaurant/Cafe/Canteen              1  AwaitingInspection
# 27                      Retailers - other           4613                   5
# 28                Restaurant/Cafe/Canteen              1                   1
# 29                  Manufacturers/packers           7839  AwaitingInspection
# ...                                   ...            ...                 ...
# 2789              Restaurant/Cafe/Canteen              1                   4
# 2790              Restaurant/Cafe/Canteen              1                   4
# 2791              Restaurant/Cafe/Canteen              1                   2
# 2792              Restaurant/Cafe/Canteen              1                   3
# 2793              Restaurant/Cafe/Canteen              1                   1
# 2794              Restaurant/Cafe/Canteen              1                   2
# 2795               Takeaway/sandwich shop           7844  AwaitingInspection
# 2796               Takeaway/sandwich shop           7844  AwaitingInspection
# 2797               Takeaway/sandwich shop           7844                   3
# 2798                    Retailers - other           4613                   5
# 2799              Restaurant/Cafe/Canteen              1                   2
# 2800                       Mobile caterer           7846  AwaitingInspection
# 2801              Restaurant/Cafe/Canteen              1                   5
# 2802                Manufacturers/packers           7839                   5
# 2803              Restaurant/Cafe/Canteen              1                   1
# 2804               Takeaway/sandwich shop           7844                   1
# 2805                Manufacturers/packers           7839  AwaitingInspection
# 2806                       Mobile caterer           7846  AwaitingInspection
# 2807                Manufacturers/packers           7839                   4
# 2808              Restaurant/Cafe/Canteen              1                   5
# 2809                    Retailers - other           4613                   4
# 2810                    Retailers - other           4613                   4
# 2811                    Retailers - other           4613              Exempt
# 2812                    Retailers - other           4613                   2
# 2813                    Retailers - other           4613                   0
# 2814              Restaurant/Cafe/Canteen              1                   4
# 2815              Restaurant/Cafe/Canteen              1                   4
# 2816                Manufacturers/packers           7839                   4
# 2817              Restaurant/Cafe/Canteen              1                   4
# 2818              Restaurant/Cafe/Canteen              1                   5
#
#                           RatingKey            RatingDate LocalAuthorityCode  \
# 0     fhrs_awaitinginspection_en-GB  {'@xsi:nil': 'true'}                509
# 1                      fhrs_5_en-GB            2017-06-14                509
# 2                      fhrs_5_en-GB            2016-01-20                509
# 3                      fhrs_4_en-GB            2015-07-14                509
# 4                      fhrs_1_en-GB            2016-01-30                509
# 5                      fhrs_5_en-GB            2016-02-17                509
# 6                      fhrs_5_en-GB            2016-03-16                509
# 7                      fhrs_2_en-GB            2017-01-23                509
# 8     fhrs_awaitinginspection_en-GB  {'@xsi:nil': 'true'}                509
# 9                 fhrs_exempt_en-GB            2016-02-12                509
# 10                fhrs_exempt_en-GB            2017-07-26                509
# 11                     fhrs_5_en-GB            2017-11-24                509
# 12                fhrs_exempt_en-GB            2016-12-21                509
# 13                     fhrs_3_en-GB            2017-01-09                509
# 14                     fhrs_4_en-GB            2017-02-06                509
# 15                     fhrs_2_en-GB            2017-02-06                509
# 16    fhrs_awaitinginspection_en-GB  {'@xsi:nil': 'true'}                509
# 17                     fhrs_5_en-GB            2017-03-01                509
# 18                     fhrs_5_en-GB            2017-10-03                509
# 19                     fhrs_2_en-GB            2017-04-10                509
# 20    fhrs_awaitinginspection_en-GB  {'@xsi:nil': 'true'}                509
# 21                     fhrs_4_en-GB            2017-03-13                509
# 22    fhrs_awaitinginspection_en-GB  {'@xsi:nil': 'true'}                509
# 23                     fhrs_0_en-GB            2017-09-27                509
# 24                     fhrs_4_en-GB            2017-02-01                509
# 25                     fhrs_1_en-GB            2017-03-09                509
# 26    fhrs_awaitinginspection_en-GB  {'@xsi:nil': 'true'}                509
# 27                     fhrs_5_en-GB            2015-08-04                509
# 28                     fhrs_1_en-GB            2017-03-11                509
# 29    fhrs_awaitinginspection_en-GB  {'@xsi:nil': 'true'}                509
# ...                             ...                   ...                ...
# 2789                   fhrs_4_en-GB            2017-02-21                509
# 2790                   fhrs_4_en-GB            2017-09-07                509
# 2791                   fhrs_2_en-GB            2017-09-12                509
# 2792                   fhrs_3_en-GB            2017-09-07                509
# 2793                   fhrs_1_en-GB            2017-10-25                509
# 2794                   fhrs_2_en-GB            2017-06-06                509
# 2795  fhrs_awaitinginspection_en-GB  {'@xsi:nil': 'true'}                509
# 2796  fhrs_awaitinginspection_en-GB  {'@xsi:nil': 'true'}                509
# 2797                   fhrs_3_en-GB            2016-04-21                509
# 2798                   fhrs_5_en-GB            2016-01-04                509
# 2799                   fhrs_2_en-GB            2017-01-14                509
# 2800  fhrs_awaitinginspection_en-GB  {'@xsi:nil': 'true'}                509
# 2801                   fhrs_5_en-GB            2017-05-05                509
# 2802                   fhrs_5_en-GB            2015-11-03                509
# 2803                   fhrs_1_en-GB            2017-01-11                509
# 2804                   fhrs_1_en-GB            2017-06-21                509
# 2805  fhrs_awaitinginspection_en-GB  {'@xsi:nil': 'true'}                509
# 2806  fhrs_awaitinginspection_en-GB  {'@xsi:nil': 'true'}                509
# 2807                   fhrs_4_en-GB            2015-12-07                509
# 2808                   fhrs_5_en-GB            2015-12-14                509
# 2809                   fhrs_4_en-GB            2015-07-27                509
# 2810                   fhrs_4_en-GB            2017-05-24                509
# 2811              fhrs_exempt_en-GB            2017-07-21                509
# 2812                   fhrs_2_en-GB            2017-10-25                509
# 2813                   fhrs_0_en-GB            2017-03-28                509
# 2814                   fhrs_4_en-GB            2017-08-01                509
# 2815                   fhrs_4_en-GB            2016-08-03                509
# 2816                   fhrs_4_en-GB            2017-03-01                509
# 2817                   fhrs_4_en-GB            2017-08-01                509
# 2818                   fhrs_5_en-GB            2017-01-26                509
#
#      LocalAuthorityName        ...                        AddressLine2  \
# 0                Ealing        ...                                 NaN
# 1                Ealing        ...                        8 Gorst Road
# 2                Ealing        ...                         Hanger Lane
# 3                Ealing        ...                           Greenford
# 4                Ealing        ...                         West Ealing
# 5                Ealing        ...                           Greenford
# 6                Ealing        ...                                 NaN
# 7                Ealing        ...                         West Ealing
# 8                Ealing        ...                        2 Portal Way
# 9                Ealing        ...                         West Ealing
# 10               Ealing        ...                            Southall
# 11               Ealing        ...                                 NaN
# 12               Ealing        ...                            Southall
# 13               Ealing        ...                              Ealing
# 14               Ealing        ...                               Acton
# 15               Ealing        ...                              Ealing
# 16               Ealing        ...                                 NaN
# 17               Ealing        ...              Palace Shopping Centre
# 18               Ealing        ...          Hanwell Town Football Club
# 19               Ealing        ...                            Southall
# 20               Ealing        ...          Alpha Beta Business Centre
# 21               Ealing        ...               Acton Business Centre
# 22               Ealing        ...                            Broadway
# 23               Ealing        ...               Acton Business Centre
# 24               Ealing        ...                      20-22 Broadway
# 25               Ealing        ...                     East Acton Lane
# 26               Ealing        ...                       Nawaris House
# 27               Ealing        ...                118 Churchfield Road
# 28               Ealing        ...                               Acton
# 29               Ealing        ...                                 NaN
# ...                 ...        ...                                 ...
# 2789             Ealing        ...                    25 St Marys Road
# 2790             Ealing        ...                         West Ealing
# 2791             Ealing        ...                               Acton
# 2792             Ealing        ...                              Ealing
# 2793             Ealing        ...               55-57 Bideford Avenue
# 2794             Ealing        ...                               Acton
# 2795             Ealing        ...                               Acton
# 2796             Ealing        ...                               Acton
# 2797             Ealing        ...                       Uxbridge Road
# 2798             Ealing        ...                           Greenford
# 2799             Ealing        ...                              Ealing
# 2800             Ealing        ...                          Park Royal
# 2801             Ealing        ...                           Noel Road
# 2802             Ealing        ...               47-49 Park Royal Road
# 2803             Ealing        ...                            Northolt
# 2804             Ealing        ...                           Greenford
# 2805             Ealing        ...                                 NaN
# 2806             Ealing        ...                                 NaN
# 2807             Ealing        ...                   7-11 Minerva Road
# 2808             Ealing        ...                              Ealing
# 2809             Ealing        ...                             Hanwell
# 2810             Ealing        ...                               Acton
# 2811             Ealing        ...                               Acton
# 2812             Ealing        ...                               Acton
# 2813             Ealing        ...                            Southall
# 2814             Ealing        ...                              Ealing
# 2815             Ealing        ...                         Hanger Lane
# 2816             Ealing        ...          Alpha Beta Business Centre
# 2817             Ealing        ...                               Acton
# 2818             Ealing        ...                               Acton
#
#              AddressLine3 AddressLine4  PostCode RightToReply Hygiene  \
# 0                     NaN          NaN       NaN          NaN     NaN
# 1              Park Royal       London  NW10 6LE          NaN       5
# 2                  Ealing          NaN    W5 3HU          NaN       5
# 3                     NaN          NaN   UB6 9AT          NaN      10
# 4                     NaN          NaN   W13 0SY          NaN      10
# 5                     NaN          NaN   UB6 0ES          NaN       0
# 6                     NaN          NaN       NaN          NaN       0
# 7                  London          NaN   W13 0LJ          NaN      10
# 8                   Acton       London    W3 6RT          NaN     NaN
# 9                     NaN          NaN   W13 8QA          NaN     NaN
# 10              Middlesex          NaN   UB2 4BX          NaN     NaN
# 11                    NaN          NaN       NaN          NaN       5
# 12              Middlesex          NaN   UB2 4DA          NaN     NaN
# 13                 London          NaN    W5 3HH          NaN      10
# 14                 London          NaN    W3 6PA          NaN       5
# 15                 London          NaN    W5 3PR          NaN      15
# 16                    NaN          NaN       NaN          NaN     NaN
# 17          14 South Road     Southall   UB1 1RT          NaN       5
# 18          Perivale Lane     Perivale   UB6 8TL          NaN       5
# 19                    NaN          NaN   UB1 1ND          NaN      10
# 20    7 - 11 Minerva Road   Park Royal  NW10 6HJ          NaN     NaN
# 21            School Road   Park Royal  NW10 6TD          NaN       0
# 22            West Ealing       London   W13 0SS          NaN     NaN
# 23            School Road   Park Royal  NW10 6TD          NaN      15
# 24            West Ealing       London   W13 0SU          NaN      10
# 25                  Acton       London    W3 7HD          NaN       5
# 26    857 Coronation Road   Park Royal  NW10 7PP          NaN     NaN
# 27                  Acton          NaN    W3 6BY          NaN       5
# 28                 London          NaN    W3 6BS          NaN      10
# 29                    NaN          NaN       NaN          NaN     NaN
# ...                   ...          ...       ...          ...     ...
# 2789               Ealing       London    W5 5RE          NaN       5
# 2790               London          NaN   W13 0SR          NaN       5
# 2791               London          NaN    W3 6ND          NaN       5
# 2792               London          NaN    W5 3QS          NaN      10
# 2793             Perivale    Middlesex   UB6 7PP          NaN      15
# 2794               London          NaN    W3 7TZ          NaN      15
# 2795               London          NaN    W3 9BH          NaN     NaN
# 2796               London          NaN    W3 6PL          NaN     NaN
# 2797               Ealing          NaN    W5 3NU          NaN       5
# 2798                  NaN          NaN   UB6 8QY          NaN       0
# 2799               London          NaN    W5 2PJ          NaN      10
# 2800               London          NaN  NW10 7PR          NaN     NaN
# 2801                Acton       London    W3 0DS          NaN       5
# 2802           Park Royal          NaN  NW10 7LQ          NaN       0
# 2803            Middlesex          NaN   UB5 4RU          NaN      15
# 2804            Middlesex          NaN   UB6 0HL          NaN      15
# 2805                  NaN          NaN       NaN          NaN     NaN
# 2806                  NaN          NaN       NaN          NaN     NaN
# 2807           Park Royal          NaN  NW10 6HJ          NaN       5
# 2808                  NaN          NaN    W5 3SS          NaN       0
# 2809                  NaN          NaN    W7 1LL          NaN      10
# 2810               London          NaN    W3 0BU          NaN       5
# 2811               London          NaN    W3 6LE          NaN     NaN
# 2812               London          NaN    W3 9RH          NaN      10
# 2813            Middlesex          NaN   UB1 2HB          NaN      10
# 2814               London          NaN    W5 4QA          NaN       5
# 2815               Ealing          NaN    W5 3HU          NaN       5
# 2816    7-11 Minerva Road   Park Royal  NW10 6HJ          NaN       0
# 2817               London          NaN    W3 7DD          NaN      10
# 2818               London          NaN    W3 9DD          NaN       0
#
#      Structural ConfidenceInManagement          Longitude           Latitude
# 0           NaN                    NaN                NaN                NaN
# 1             5                      5  -0.26322300000000  51.52740500000000
# 2             5                      5  -0.29072000000000  51.51686500000000
# 3             0                      5  -0.35438900000000  51.51866600000000
# 4             5                     20  -0.32524100000000  51.51054700000000
# 5             0                      0  -0.34366700000000  51.55002400000000
# 6             0                      0                NaN                NaN
# 7            15                     10  -0.32046700000000  51.51377000000000
# 8           NaN                    NaN  -0.26297700405121  51.52098846435550
# 9           NaN                    NaN  -0.31534900000000  51.51617000000000
# 10          NaN                    NaN  -0.37827900052071  51.50225448608400
# 11            5                      5                NaN                NaN
# 12          NaN                    NaN  -0.38261700000000  51.50180200000000
# 13           10                     10  -0.29180200000000  51.51336500000000
# 14           10                      5  -0.26945200000000  51.51367600000000
# 15            5                     10  -0.29811000000000  51.50846600000000
# 16          NaN                    NaN                NaN                NaN
# 17            5                      5  -0.37626400000000  51.51067100000000
# 18            5                      5  -0.32758599519730  51.53227996826170
# 19           15                     10  -0.38760900000000  51.51263500000000
# 20          NaN                    NaN  -0.26392000000000  51.52953700000000
# 21            0                     10  -0.25845700000000  51.52575200000000
# 22          NaN                    NaN  -0.32067200541496  51.51094055175780
# 23           20                     20  -0.25845700000000  51.52575200000000
# 24            5                      5  -0.32223800000000  51.51068400000000
# 25           15                     20  -0.24995000000000  51.51261300000000
# 26          NaN                    NaN  -0.27000300000000  51.52957300000000
# 27            5                      5  -0.26959300000000  51.50844500000000
# 28           15                     20  -0.27050700000000  51.50828700000000
# 29          NaN                    NaN                NaN                NaN
# ...         ...                    ...                ...                ...
# 2789         10                      5  -0.30412500000000  51.50713200000000
# 2790         10                      5  -0.32005101442337  51.51098632812500
# 2791         15                     10  -0.26586401462555  51.50647354125980
# 2792          5                     10  -0.29198300838471  51.52896881103520
# 2793         15                     20  -0.31851398944855  51.53629302978520
# 2794         10                     10  -0.25117400288582  51.51417922973630
# 2795        NaN                    NaN  -0.27591699361801  51.50850296020510
# 2796        NaN                    NaN  -0.26710200309753  51.51638412475590
# 2797         10                     10  -0.28837200000000  51.51031200000000
# 2798          0                      5  -0.35239700000000  51.52835000000000
# 2799         15                     10  -0.30035600000000  51.51432500000000
# 2800        NaN                    NaN  -0.27189000000000  51.52808100000000
# 2801          5                      5  -0.28987000000000  51.51727000000000
# 2802          0                      0  -0.26585900000000  51.52669700000000
# 2803         15                     20  -0.35051700000000  51.55121700000000
# 2804         15                     20  -0.33910661617092  51.55180881758250
# 2805        NaN                    NaN                NaN                NaN
# 2806        NaN                    NaN                NaN                NaN
# 2807         10                      0  -0.26392100000000  51.52953800000000
# 2808          5                      5  -0.30217700000000  51.51341700000000
# 2809          0                      5  -0.33706300000000  51.51435700000000
# 2810          5                     10  -0.26584801077843  51.51902770996090
# 2811        NaN                    NaN  -0.26713201403618  51.50685119628910
# 2812         15                     10  -0.28063899278641  51.50824737548830
# 2813         20                     30  -0.36434203047224  51.52438167550050
# 2814         10                      5  -0.30719900000000  51.50351700000000
# 2815         10                      5  -0.29072100000000  51.51686600000000
# 2816          5                     10  -0.26392000000000  51.52953700000000
# 2817          0                     10  -0.24968500000000  51.51465900000000
# 2818          0                      0  -0.27263000000000  51.50739200000000
#
# [2819 rows x 25 columns]
